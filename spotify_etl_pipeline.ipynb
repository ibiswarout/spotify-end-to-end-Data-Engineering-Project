# %%
pip install spotipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 64 kB 277 kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 129 kB 64 kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 278 kB 302 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 157 kB 214 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 201 kB 248 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 70 kB 284 kB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
# Out:
# /Users/biswarout/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
clientcredentialmanager = SpotifyClientCredentials(client_id="f5b11f25f1114ef6a6bce75352e4e0d0", client_secret="296e8b6b820645949f814171265a1566")

# %%
sp = spotipy.Spotify(client_credentials_manager=clientcredentialmanager)

# %%
playlist_link = "https://open.spotify.com/playlist/5ABHKGoOzxkaa28ttQV9sE"

# %%
playlist_uri = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
len(data['items'])
# Out:
# 100

# %%
data['items'][0]['track']['album']['id']
# Out:
# '4yP0hdKOZPNshxUOjY0cZj'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'After Hours'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2020-03-20'

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_track = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'album_name':album_name, 'release_date':album_release_date, 'total_track':album_total_track,'url':album_url }
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'album_name': 'After Hours',
#   'release_date': '2020-03-20',
#   'total_track': 14,
#   'url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#  {'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'album_name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_track': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': '09fggMHib4YkOtwQNXEBII',
#   'album_name': 'Starboy',
#   'release_date': '2016-11-25',
#   'total_track': 18,
#   'url': 'https://open.spotify.com/album/09fggMHib4YkOtwQNXEBII'},
#  {'album_id': '5658aM19fA3JVwTK6eQX70',
#   'album_name': 'Divinely Uninspired To A Hellish Extent',
#   'release_date': '2019-05-17',
#   'total_track': 12,
#   'url': 'https://open.spotify.com/album/5658aM19fA3JVwTK6eQX70'},
#  {'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'album_name': "Harry's House",
#   'release_date': '2022-05-20',
#   'total_track': 13,
# ...

# %%
data['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#   'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#   'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'The Weeknd',
#   'type': 'artist',
#   'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#   'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#   'id': '4tZwfgrHOc3mvqYlEYSvVi',
#   'name': 'Daft Punk',
#   'type': 'artist',
#   'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track' :
            for artist in value['artists']:
                artist_dict = {'artist_id': artist['id'], 'name': artist['name'], 'external_url':artist['external_urls']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'The Weeknd',
#   'external_url': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'}},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'name': 'Ed Sheeran',
#   'external_url': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'}},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'The Weeknd',
#   'external_url': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'}},
#  {'artist_id': '4tZwfgrHOc3mvqYlEYSvVi',
#   'name': 'Daft Punk',
#   'external_url': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'}},
#  {'artist_id': '4GNC7GD6oZMSxPGyXy4MNB',
#   'name': 'Lewis Capaldi',
#   'external_url': {'spotify': 'https://open.spotify.com/artist/4GNC7GD6oZMSxPGyXy4MNB'}},
#  {'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'name': 'Harry Styles',
#   'external_url': {'spotify': 'https://open.spotify.com/artist/6KImCVD70vtIoJWnq6nGn3'}},
# ...

# %%
data['items'][0]['track']['album']['artists'][0]['id']
# Out:
# '1Xyo4u8uXC1ZmMpatF05PJ'

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id, 'song_name':song_name, 'duration':song_duration, 'url': song_url, 'popularity':song_popularity, 'Added on': song_added, 'album_id':album_id, 'artist_id':artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '0VjIjW4GlUZAMYd2vXMi3b',
#   'song_name': 'Blinding Lights',
#   'duration': 200040,
#   'url': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b',
#   'popularity': 92,
#   'Added on': '2024-02-15T21:57:53Z',
#   'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '7qiZfU4dY1lWllzX7mPBI3',
#   'song_name': 'Shape of You',
#   'duration': 233712,
#   'url': 'https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3',
#   'popularity': 92,
#   'Added on': '2024-02-15T21:57:53Z',
#   'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '5aAx2yezTd8zXrkmtKl66Z',
#   'song_name': 'Starboy',
#   'duration': 230453,
#   'url': 'https://open.spotify.com/track/5aAx2yezTd8zXrkmtKl66Z',
#   'popularity': 6,
#   'Added on': '2024-02-15T21:57:53Z',
#   'album_id': '09fggMHib4YkOtwQNXEBII',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '7qEHsqek33rTcFNT9PFqLf',
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                               album_name  \
# 0  4yP0hdKOZPNshxUOjY0cZj                              After Hours
# 1  3T4tUhGYeRNVUGevb0wThu                               ÷ (Deluxe)
# 2  09fggMHib4YkOtwQNXEBII                                  Starboy
# 3  5658aM19fA3JVwTK6eQX70  Divinely Uninspired To A Hellish Extent
# 4  5r36AJ6VOJtp00oxSkBZ5h                            Harry's House
#
#   release_date  total_track                                                url
# 0   2020-03-20           14  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1   2017-03-03           16  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2   2016-11-25           18  https://open.spotify.com/album/09fggMHib4YkOtw...
# 3   2019-05-17           12  https://open.spotify.com/album/5658aM19fA3JVwT...
# 4   2022-05-20           13  https://open.spotify.com/album/5r36AJ6VOJtp00o...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   album_name    100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_track   100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id           name  \
# 0  1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 1  6eUKZXaKkcviH0Ku9w2n3V     Ed Sheeran
# 2  1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 3  4tZwfgrHOc3mvqYlEYSvVi      Daft Punk
# 4  4GNC7GD6oZMSxPGyXy4MNB  Lewis Capaldi
#
#                                         external_url
# 0  {'spotify': 'https://open.spotify.com/artist/1...
# 1  {'spotify': 'https://open.spotify.com/artist/6...
# 2  {'spotify': 'https://open.spotify.com/artist/1...
# 3  {'spotify': 'https://open.spotify.com/artist/4...
# 4  {'spotify': 'https://open.spotify.com/artist/4...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     129 non-null    object
#  1   name          129 non-null    object
#  2   external_url  129 non-null    object
# dtypes: object(3)
# memory usage: 3.1+ KB

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id          song_name  duration  \
# 0  0VjIjW4GlUZAMYd2vXMi3b    Blinding Lights    200040
# 1  7qiZfU4dY1lWllzX7mPBI3       Shape of You    233712
# 2  5aAx2yezTd8zXrkmtKl66Z            Starboy    230453
# 3  7qEHsqek33rTcFNT9PFqLf  Someone You Loved    182160
# 4  4Dvkj6JhhA12EX05fT7y2e          As It Was    167303
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0VjIjW4GlUZAMYd...          92
# 1  https://open.spotify.com/track/7qiZfU4dY1lWllz...          92
# 2  https://open.spotify.com/track/5aAx2yezTd8zXrk...           6
# 3  https://open.spotify.com/track/7qEHsqek33rTcFN...          89
# 4  https://open.spotify.com/track/4Dvkj6JhhA12EX0...          92
#
#                Added on                album_id               artist_id
# 0  2024-02-15T21:57:53Z  4yP0hdKOZPNshxUOjY0cZj  1Xyo4u8uXC1ZmMpatF05PJ
# 1  2024-02-15T21:57:53Z  3T4tUhGYeRNVUGevb0wThu  6eUKZXaKkcviH0Ku9w2n3V
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   song_id     100 non-null    object
#  1   song_name   100 non-null    object
#  2   duration    100 non-null    int64
#  3   url         100 non-null    object
#  4   popularity  100 non-null    int64
#  5   Added on    100 non-null    object
#  6   album_id    100 non-null    object
#  7   artist_id   100 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.4+ KB

# %%
album_df = album_df.drop_duplicates(subset='album_id')

# %%
artist_df = artist_df.drop_duplicates(subset='artist_id')

# %%
song_df = song_df.drop_duplicates(subset='song_id')

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'],format='mixed')

# %%
album_df['release_date'].unique()
# Out:
# <DatetimeArray>
# ['2020-03-20 00:00:00', '2017-03-03 00:00:00', '2016-11-25 00:00:00',
#  '2019-05-17 00:00:00', '2022-05-20 00:00:00', '2018-12-14 00:00:00',
#  '2013-04-22 00:00:00', '2016-05-06 00:00:00', '2021-07-23 00:00:00',
#  '2017-06-23 00:00:00', '2020-06-29 00:00:00', '2018-04-19 00:00:00',
#  '2016-07-29 00:00:00', '2025-05-12 00:00:00', '2016-10-28 00:00:00',
#  '2019-10-17 00:00:00', '2025-04-09 00:00:00', '2017-09-15 00:00:00',
#  '2017-04-07 00:00:00', '2014-09-08 00:00:00', '2013-09-09 00:00:00',
#  '2025-02-07 00:00:00', '2000-07-10 00:00:00', '2014-11-06 00:00:00',
#  '2013-06-24 00:00:00', '2015-04-06 00:00:00', '2019-12-13 00:00:00',
#  '2019-06-21 00:00:00', '2025-05-27 00:00:00', '2013-01-01 00:00:00',
#  '2014-06-21 00:00:00', '2025-04-25 00:00:00', '2020-03-27 00:00:00',
#  '2019-08-23 00:00:00', '2012-10-09 00:00:00', '2018-12-10 00:00:00',
#  '2016-09-16 00:00:00', '2025-06-19 00:00:00', '2019-09-06 00:00:00',
# ...

# %%
song_df['Added on'] = pd.to_datetime(song_df['Added on'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   song_id     100 non-null    object
#  1   song_name   100 non-null    object
#  2   duration    100 non-null    int64
#  3   url         100 non-null    object
#  4   popularity  100 non-null    int64
#  5   Added on    100 non-null    datetime64[ns, UTC]
#  6   album_id    100 non-null    object
#  7   artist_id   100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
